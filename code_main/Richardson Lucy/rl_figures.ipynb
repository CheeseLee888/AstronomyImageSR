# %% [markdown]
# # Richardson Lucy Visualization
#
# This notebook was created to visualize the experiments conducted for Richardson Lucy deconvolution.

# %%
import astropy
from astropy.io import fits
from astropy.visualization import astropy_mpl_style
from astropy.utils.data import get_pkg_data_filename
from astropy.convolution import Gaussian2DKernel, convolve
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### PSF with stddev = 4

# %%
df_psnr = pd.read_csv("rl_psnr_4_001.csv").iloc[:, -2: ]
df_ssim = pd.read_csv("rl_ssim_4_001.csv").iloc[:, -2: ]
df_sssim = pd.read_csv("rl_sssim_4_001.csv").iloc[:, -2: ]

# %%
df_ssim
# Out:
#      best_score  epoch_no
# 0      0.667433        49
# 1      0.733697         3
# 2      0.847722         0
# 3      0.799757         0
# 4      0.672132        49
# ..          ...       ...
# 469    0.825113         0
# 470    0.665461        49
# 471    0.680796        49
# 472    0.849914         0
# 473    0.695714        17
#
# [474 rows x 2 columns]

# %%
df_sssim.shape[0]
# Out:
# 474

# %%
print(df_sssim['epoch_no'].mean())
print(df_ssim['epoch_no'].mean())
print(df_psnr['epoch_no'].mean())
# Out:
# 2.9894514767932487
# 30.00632911392405
# 3.9430379746835444

# %%
# df_ssim = df_ssim.iloc[:,1:-9]
# df_sssim = df_sssim.iloc[:,1:-9]
# df_psnr = df_psnr.iloc[:,1:-9]

# %%
# best_epochs = df_sssim.idxmax(axis=0) # best epochs is based on sssim
# print(best_epochs.iloc[:])
# print(np.mean(best_epochs))

# %%
# best_epochs.to_csv('best_epochs_rl.csv', sep=',', index=False)

# %%
# best_ssim = []
# best_sssim = []
# best_psnr = []
# for i in range(df_sssim.shape[1]):
#     best_ssim.append(df_ssim.iloc[best_epochs[i], i])
#     best_sssim.append(df_sssim.iloc[best_epochs[i], i])
#     best_psnr.append(df_psnr.iloc[best_epochs[i], i])

# %%
# psnr_mean = np.array(best_psnr).mean()
# psnr_std = np.array(best_psnr).std()

# ssim_mean = np.array(best_ssim).mean()
# ssim_std = np.array(best_ssim).std()

# sssim_mean = np.array(best_sssim).mean()
# sssim_std = np.array(best_sssim).std()

# %%
# print(psnr_mean, psnr_std)
# print(ssim_mean, ssim_std)
# print(sssim_mean, sssim_std)
# Out:
# 39.630224616072795 1.9725426560924386
# 0.7651713050705665 0.06582651078004104
# 0.8941468664007195 0.09946345989207661

# %%
print(df_sssim['best_score'].mean())
print(df_sssim['best_score'].std())
# Out:
# 0.6818666627261206
# 0.1095802098454643

# %%
print(df_ssim['best_score'].mean())
print(df_ssim['best_score'].std())
# Out:
# 0.7331697490647875
# 0.08811041843740147

# %%
print(df_psnr['best_score'].mean())
print(df_psnr['best_score'].std())
# Out:
# 42.39371257894653
# 2.6102022930944844

# %%
plt.figure()
plt.hist(df_ssim['best_score'], bins=10, alpha=0.5, color='purple', edgecolor='black', label='SSIM')
plt.hist(df_sssim['best_score'], bins=20, alpha=0.5, color='limegreen', edgecolor='black', label='Selective SSIM')
plt.title("stddev=4, noise=0.01")
plt.legend(fontsize=12)
plt.xlabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0, xmax=1)
plt.savefig("rl_ssim_plot_4_001.png")

# %%
# plt.figure()
# plt.hist(best_psnr, bins=10, alpha=0.5, color='purple', edgecolor='black', label='PSNR')
# #plt.title("Histogram of SSIM and Selective SSIM index values ")
# plt.legend(fontsize=12)
# plt.xlabel('Score', fontsize=12)
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# plt.xlim(xmin=0)
# plt.savefig("rl_psnr_results.png")

# %% [markdown]
# ### PSF with stddev = 10

# %%
df_psnr_10 = pd.read_csv("rl_psnr_10_001.csv").iloc[:, -2: ]
df_ssim_10 = pd.read_csv("rl_ssim_10_001.csv").iloc[:, -2: ]
df_sssim_10 = pd.read_csv("rl_sssim_10_001.csv").iloc[:, -2: ]

# %%
df_ssim_10
# Out:
#      best_score  epoch_no
# 0      0.669903        49
# 1      0.946392        10
# 2      0.829392         0
# 3      0.666081        49
# 4      0.671455        49
# ..          ...       ...
# 469    0.829024         0
# 470    0.832660         0
# 471    0.689587        49
# 472    0.681722        49
# 473    0.841772         6
#
# [474 rows x 2 columns]

# %%
print(df_sssim_10['epoch_no'].mean())
print(df_ssim_10['epoch_no'].mean())
print(df_psnr_10['epoch_no'].mean())
# Out:
# 2.5253164556962027
# 32.61392405063291
# 5.784810126582278

# %%
print(df_sssim_10['best_score'].mean())
print(df_sssim_10['best_score'].std())
# Out:
# 0.6729528552494974
# 0.11940599299222429

# %%
print(df_ssim_10['best_score'].mean())
print(df_ssim_10['best_score'].std())
# Out:
# 0.7321337780871975
# 0.08096426101374037

# %%
print(df_psnr_10['best_score'].mean())
print(df_psnr_10['best_score'].std())
# Out:
# 41.623375578771665
# 3.109064243147636

# %%
plt.figure()
plt.hist(df_ssim_10['best_score'], bins=10, alpha=0.5, color='purple', edgecolor='black', label='SSIM')
plt.hist(df_sssim_10['best_score'], bins=20, alpha=0.5, color='limegreen', edgecolor='black', label='Selective SSIM')
plt.title("stddev=10, noise=0.01")
plt.legend(fontsize=12)
plt.xlabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0, xmax=1)
plt.savefig("rl_ssim_plot_10_001.png")

# %%
plt.figure()
plt.hist(best_psnr, bins=10, alpha=0.5, color='purple', edgecolor='black', label='PSNR')
#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0)
plt.savefig("rl_psnr_results_10.png")

# %% [markdown]
# ### PSF with stddev = 10, 0.015 x noise

# %%
df_psnr_10_0015 = pd.read_csv("rl_psnr_10_0015.csv").iloc[:, -2: ]
df_ssim_10_0015 = pd.read_csv("rl_ssim_10_0015.csv").iloc[:, -2: ]
df_sssim_10_0015 = pd.read_csv("rl_sssim_10_0015.csv").iloc[:, -2: ]

# %%
df_sssim_10_0015
# Out:
#      best_score  epoch_no
# 0      0.442473         0
# 1      0.564082        22
# 2      0.445652         0
# 3      0.434763         0
# 4      0.453218         0
# ..          ...       ...
# 469    0.438003         0
# 470    0.451531         0
# 471    0.468855         0
# 472    0.716531         0
# 473    0.496389         8
#
# [474 rows x 2 columns]

# %%
print(df_sssim_10_0015['epoch_no'].mean())
print(df_ssim_10_0015['epoch_no'].mean())
print(df_psnr_10_0015['epoch_no'].mean())
# Out:
# 1.280590717299578
# 48.28902953586498
# 2.280590717299578

# %%
print(df_sssim_10_0015['best_score'].mean())
print(df_sssim_10_0015['best_score'].std())
# Out:
# 0.5170560683504941
# 0.12930019912241703

# %%
print(df_ssim_10_0015['best_score'].mean())
print(df_ssim_10_0015['best_score'].std())
# Out:
# 0.5959596491815672
# 0.09196897277865644

# %%
print(df_psnr_10_0015['best_score'].mean())
print(df_psnr_10_0015['best_score'].std())
# Out:
# 39.10813550506463
# 2.726593485628437

# %%
plt.figure()
plt.hist(df_ssim_10_0015['best_score'], bins=10, alpha=0.5, color='purple', edgecolor='black', label='SSIM')
plt.hist(df_sssim_10_0015['best_score'], bins=20, alpha=0.5, color='limegreen', edgecolor='black', label='Selective SSIM')
plt.title("stddev=10, noise=0.015")
plt.legend(fontsize=12)
plt.xlabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0, xmax=1)
plt.savefig("rl_ssim_plot_10_0015.png")

# %%
plt.figure()
plt.hist(best_psnr, bins=10, alpha=0.5, color='purple', edgecolor='black', label='PSNR')
#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0)
plt.savefig("rl_psnr_results_10_0015.png")

# %% [markdown]
# ### Show examples

# %%
example_files = ["/home/julia/hr_images/20042790.fits",
                 "/home/julia/hr_images/20043513.fits",
                 "/home/julia/hr_images/20160226.fits"]

filenames = ["20042790.png", 
             "20043513.png",
             "20160226.png"]

# %%
from PIL import Image

ind = 0
for filename in example_files:
    # lr images
    filename_lr = '/home/julia/lr_images/lr_' + filename.split("/")[-1]
    filename_lr_10 = '/home/julia/lr_images_10/lr_' + filename.split("/")[-1]
    filename_lr_10_0015 = '/home/julia/lr_images_10_noise_0015/lr_' + filename.split("/")[-1]

    #rl images
    filename_rl = '/home/julia/understanding-unets-master/rl_images/rl_images/rl_' + filename.split("/")[-1]
    filename_rl_10 = '/home/julia/understanding-unets-master/rl_images/rl_images_10/rl_' + filename.split("/")[-1]
    filename_rl_10_0015 = '/home/julia/understanding-unets-master/rl_images/rl_images_10_0015/rl_' + filename.split("/")[-1]
    
    ##### get and save hr files
    image_file = get_pkg_data_filename(filename)
    imarray = fits.getdata(image_file, ext=0)
    imarray = imarray.astype(np.float32)
    
    imarray_saved = (((imarray - imarray.min()) / (imarray.max() - imarray.min())) * 255.9).astype(np.uint8)
    img = Image.fromarray(imarray_saved)
    img.save("png_files/" + filenames[ind])
    
    ###### get and save lr image files
    
    # lr image with PSF 4
    image_file = get_pkg_data_filename(filename_lr)
    imarray = fits.getdata(image_file, ext=0)
    imarray = imarray.astype(np.float32)
    
    imarray_saved = (((imarray - imarray.min()) / (imarray.max() - imarray.min())) * 255.9).astype(np.uint8)
    img = Image.fromarray(imarray_saved)
    img.save("png_files/" + "lr_" + filenames[ind])
    
    # lr image with PSF 10
    image_file = get_pkg_data_filename(filename_lr_10)
    imarray = fits.getdata(image_file, ext=0)
    imarray = imarray.astype(np.float32)
    
    imarray_saved = (((imarray - imarray.min()) / (imarray.max() - imarray.min())) * 255.9).astype(np.uint8)
    img = Image.fromarray(imarray_saved)
    img.save("png_files/" + "lr_10_" + filenames[ind])
    
    # lr image with PSF 10, noise 0.015
    image_file = get_pkg_data_filename(filename_lr_10_0015)
    imarray = fits.getdata(image_file, ext=0)
    imarray = imarray.astype(np.float32)
    
    # save hr images
    imarray_saved = (((imarray - imarray.min()) / (imarray.max() - imarray.min())) * 255.9).astype(np.uint8)
    img = Image.fromarray(imarray_saved)
    img.save("png_files/" + "lr_10_0015_" + filenames[ind])
    
    ###### get and save rl image files
    
    # rl image from lr image with PSF 4
    image_file = get_pkg_data_filename(filename_rl)
    imarray = fits.getdata(image_file, ext=0)
    imarray = imarray.astype(np.float32)
    
    imarray_saved = (((imarray - imarray.min()) / (imarray.max() - imarray.min())) * 255.9).astype(np.uint8)
    img = Image.fromarray(imarray_saved)
    img.save("png_files/" + "rl_" + filenames[ind])
    
    # rl image from lr image with PSF 10
    image_file = get_pkg_data_filename(filename_rl_10)
    imarray = fits.getdata(image_file, ext=0)
    imarray = imarray.astype(np.float32)
    
    imarray_saved = (((imarray - imarray.min()) / (imarray.max() - imarray.min())) * 255.9).astype(np.uint8)
    img = Image.fromarray(imarray_saved)
    img.save("png_files/" + "rl_10_" + filenames[ind])
    
    # rl image from lr image with PSF 10 and noise 0.015
    image_file = get_pkg_data_filename(filename_rl_10_0015)
    imarray = fits.getdata(image_file, ext=0)
    imarray = imarray.astype(np.float32)
    
    imarray_saved = (((imarray - imarray.min()) / (imarray.max() - imarray.min())) * 255.9).astype(np.uint8)
    img = Image.fromarray(imarray_saved)
    img.save("png_files/" + "rl_10_0015_" + filenames[ind])
    
    ind += 1

# %%
# get index of example images
import glob
indices = [0,0,0]
ind = 0
for filename in glob.glob('/home/julia/hr_images/*.fits'):
    if "/home/julia/hr_images/20042790.fits" == filename:
        indices[0] = ind
    if "/home/julia/hr_images/20043513.fits" == filename:
        indices[1] = ind
    if "/home/julia/hr_images/20160226.fits" == filename:
        indices[2] = ind
    ind += 1

# %%
indices
# Out:
# [919, 638, 1210]

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim.iloc[:,919], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim.iloc[:,919], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs.iloc[919]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_ssim_iters_20042790.png")

# %%
print(df_ssim.iloc[best_epochs.iloc[919],919])
print(df_sssim.iloc[best_epochs.iloc[919],919])
print(df_psnr.iloc[best_epochs.iloc[919],919])
# Out:
# 0.7674825191497803
# 0.9427996277809144
# 40.69959259033203

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr.iloc[:,919], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs.iloc[919]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_psnr_iters_20042790.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim.iloc[:,638], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim.iloc[:,638], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs.iloc[638]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_ssim_iters_20043513.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr.iloc[:,638], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs.iloc[638]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_psnr_iters_20043513.png")

# %%
print(df_ssim.iloc[best_epochs.iloc[638],638])
print(df_sssim.iloc[best_epochs.iloc[638],638])
print(df_psnr.iloc[best_epochs.iloc[638],638])
# Out:
# 0.7828881740570068
# 0.9452014565467834
# 40.579078674316406

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim.iloc[:,1210], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim.iloc[:,1210], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs.iloc[1210]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')


#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_ssim_iters_20160226.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr.iloc[:,1210], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs.iloc[1210]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_psnr_iters_20160226.png")

# %%
print(df_ssim.iloc[best_epochs.iloc[1210],1210])
print(df_sssim.iloc[best_epochs.iloc[1210],1210])
print(df_psnr.iloc[best_epochs.iloc[1210],1210])
# Out:
# 0.7765690088272095
# 0.9564778208732604
# 40.59114074707031

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim_10.iloc[:,919], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim_10.iloc[:,919], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs_10.iloc[919]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_10_ssim_iters_20042790.png")

# %%
print(df_ssim_10.iloc[best_epochs_10.iloc[919],919])
print(df_sssim_10.iloc[best_epochs_10.iloc[919],919])
print(df_psnr_10.iloc[best_epochs_10.iloc[919],919])
# Out:
# 0.7721645832061768
# 0.8403598070144653
# 37.58180236816406

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr_10.iloc[:,919], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs_10.iloc[919]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_10_psnr_iters_20042790.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim_10.iloc[:,638], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim_10.iloc[:,638], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs_10.iloc[638], color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_10_ssim_iters_20043513.png")

# %%
print(df_ssim_10.iloc[best_epochs_10.iloc[638],638])
print(df_sssim_10.iloc[best_epochs_10.iloc[638],638])
print(df_psnr_10.iloc[best_epochs_10.iloc[638],638])
# Out:
# 0.7783622145652771
# 0.8818226456642151
# 38.06291198730469

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr_10.iloc[:,638], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs_10.iloc[638], color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_10_psnr_iters_20043513.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim_10.iloc[:,1210], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim_10.iloc[:,1210], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs_10.iloc[1210]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12, loc="lower right")
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_10_ssim_iters_20160226.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr_10.iloc[:,1210], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs_10.iloc[1210]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12, loc= "lower right")
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_10_psnr_iters_20160226.png")

# %%
print(df_ssim_10.iloc[best_epochs_10.iloc[1210],1210])
print(df_sssim_10.iloc[best_epochs_10.iloc[1210],1210])
print(df_psnr_10.iloc[best_epochs_10.iloc[1210],1210])
# Out:
# 0.7598878741264343
# 0.8654842972755432
# 33.28627014160156

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim_10_0015.iloc[:,919], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim_10_0015.iloc[:,919], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs_10_0015.iloc[919]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_10_0015_ssim_iters_20042790.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr_10_0015.iloc[:,919], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs_10_0015.iloc[919]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12, loc="lower right")
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_10_0015_psnr_iters_20042790.png")

# %%
print(df_ssim_10_0015.iloc[best_epochs_10_0015.iloc[919],919])
print(df_sssim_10_0015.iloc[best_epochs_10_0015.iloc[919],919])
print(df_psnr_10_0015.iloc[best_epochs_10_0015.iloc[919],919])
# Out:
# 0.6346235275268555
# 0.8285609483718872
# 35.7144775390625

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim_10_0015.iloc[:,638], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim_10_0015.iloc[:,638], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs_10_0015.iloc[638]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_10_0015_ssim_iters_20043513.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr_10_0015.iloc[:,638], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs_10_0015.iloc[638]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12, loc= "lower right")
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_10_0015_psnr_iters_20043513.png")

# %%
print(df_ssim_10_0015.iloc[best_epochs_10_0015.iloc[638],638])
print(df_sssim_10_0015.iloc[best_epochs_10_0015.iloc[638],638])
print(df_psnr_10_0015.iloc[best_epochs_10_0015.iloc[638],638])
# Out:
# 0.6464354395866394
# 0.8846155405044556
# 36.67486572265625

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_ssim_10_0015.iloc[:,1210], alpha=0.8, color='purple', label='SSIM')
plt.plot(iterations, df_sssim_10_0015.iloc[:,1210], alpha=0.8, color='green', label='Selective SSIM')
plt.axvline(x = best_epochs_10_0015.iloc[1210]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=1)
plt.savefig("png_files/rl_10_0015_ssim_iters_20160226.png")

# %%
iterations = np.linspace(1,50,50)
plt.figure()
plt.plot(iterations, df_psnr_10_0015.iloc[:,1210], alpha=0.8, color='purple', label='PSNR')
plt.axvline(x = best_epochs_10_0015.iloc[1210]+1, color = 'teal', linestyle='--', label = 'Best SSSIM Iteration')

#plt.title("Histogram of SSIM and Selective SSIM index values ")
plt.legend(fontsize=12, loc="lower right")
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('PSNR Score', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(xmin=0.5,xmax=50)
plt.ylim(ymin=0, ymax=45)
plt.savefig("png_files/rl_10_0015_psnr_iters_20160226.png")

# %%
print(df_ssim_10_0015.iloc[best_epochs_10_0015.iloc[1210],1210])
print(df_sssim_10_0015.iloc[best_epochs_10_0015.iloc[1210],1210])
print(df_psnr_10_0015.iloc[best_epochs_10_0015.iloc[1210],1210])
# Out:
# 0.6531407833099365
# 0.8427826166152954
# 35.33537292480469
